# %%
print('hello world')
# Out:
# hello world

# %%
print("hello world")
# Out:
# hello world

# %%
x=12
print(x)
print('x')
# Out:
# 12
# x

# %%
print('x=10')
# Out:
# x=10

# %%
print('x=',x)
# Out:
# x= 12

# %%
x=15
print(x)
# Out:
# 15

# %%
print(x)
# Out:
# 12
